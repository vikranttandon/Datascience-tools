# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.pie?

# %%
plt.style.use('seaborn')

# %%
subjects = ['Oxygen','Nitrogen','rest']
marks = [21,78,1]

plt.pie(marks,labels=subjects,shadow=True,explode = (0.1,0,0),
        colors=('green','brown','yellow'),autopct='%.2f') 
# We can also show values along with percentage
plt.title('Air composition')
plt.show()
